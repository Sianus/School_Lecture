# %% [markdown]
# # Data Indexing and Selection

# %% [markdown]
# NumPy array처럼 상당히 비슷하게 Pandas ``Series``와  ``DataFrame`` object 내 데이터에 접근한다.

# %% [markdown]
# ## Data Selection in Series

# %% [markdown]
# ### Series as dictionary

# %% [markdown]
# Series = Data형 고정 => 빠름
#
# Dictionary = data형 자유로움.

# %%
import pandas as pd
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# 0.5

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
for index, value in data.items(): # for loop 미사용 권장. 벡터화된 연산이 가능하기때문 -> 벡터연산 힘들 때에만 사용.
    print(f"index = {index} value = {value}")
    # f = format = c언어의 %와 같은 역할. {}안에 변수명 작성함으로써 실행
# Out:
# index = a value = 0.25
# index = b value = 0.5
# index = c value = 0.75
# index = d value = 1.0

# %%
list(data.items()) # DataFrame와 비교
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %% [markdown]
# ### Series as one-dimensional array

# %% [markdown]
# NumPy array의 *slices*, *masking*,  *fancy indexing* 등이 가능하다.

# %%
# slicing by explicit index
data['a':'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
data.loc['a':'c'] #위와 동일 # explicit index 표현임을 명확하게 해주는 loc
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %% [markdown]
# 주의) 'c'  index 결과가 *포함* 된다.

# %%
# slicing by implicit integer index
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
data.iloc[0:2] # 위와 동일 # implicit임을 명확하게 제시하는 iloc (당분간은 loc와 iloc을 사용하면서 형태에 익숙해질 것)
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# masking => 조건을 만족하는 값들을 출력하는 것
data[(data > 0.3) & (data < 0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
(data > 0.3) & (data < 0.8) # 논리 연산자 사용 시 괄호 필수!! 논리연산자들이 관계연산자들보다 계산 우선 순위가 빠름
# Out:
# a    False
# b     True
# c     True
# d    False
# e    False
# dtype: bool

# %%
# fancy indexing
data[['a', 'e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %% [markdown]
# ### Indexers: loc, iloc, and ix
#
# 정수 index가 사용되는 경우 아래 예처럼 explicit index(아래 data[1])인지  implicit Python-style index(아래 ``data[1:3]``)인지 애매한 경우가 생긴다.

# %%
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
# explicit index when indexing
data[1]
# Out:
# 'a'

# %%
# implicit index when slicing
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# 이러한 혼돈을 피하기 위해 ``Series``에는 다음과 같은 attribute들을 제공한다.
#
#
# 먼저, ``loc`` explicit index로 접근을 한다.

# %%
data.loc[1]
# Out:
# 'a'

# %%
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %% [markdown]
# 반면, ``iloc`` attribute implicit Python-style index 형태로 접근한다.

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# ``ix``은 혼합된 형태이며  ``DataFrame`` object에서 설명한다.

# %% [markdown]
# ## Data Selection in DataFrame

# %% [markdown]
# ### DataFrame as a dictionary

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %% [markdown]
# 다음과 같이 각 column을 나타내는 ``Series`` object에 접근할 수 있다.

# %%
data['area'] # Dictionary 와 유사한 사용방법
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# attribute-style access 도 가능하다.

# %%
data.area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area is data['area']
# Out:
# True

# %% [markdown]
# 주의) column name이 문자열이 아니거나 이미 그런 attribute name(이미 존재하는 data의 method이거나 attributes)이 존재하는 경우 사용할 수 없다.

# %%
data.pop is data['pop']
# Out:
# False

# %%
x = data['pop']

# %%
data.pop('pop') # method pop = 삭제
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# Name: pop, dtype: int64

# %%
data['pop'] =x

# %% [markdown]
# Dictionary-style access가 보다 안전하며 새로운 column으로 추가시킬 수도 있다.

# %%
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# ### DataFrame as two-dimensional array
#
# ``values`` attribute를 통해 순수 데이터 array를 access 할 수 있다.

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.83325210e+07, 9.04139261e+01],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %% [markdown]
# 전체 `DataFrame``의 row와 column들을 swap할 수 있다.

# %%
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %% [markdown]
# NumPy array 에서의 작업이 또한 편리할 수도 있다.

# %%
data.values[0]
# Out:
# array([4.23967000e+05, 3.83325210e+07, 9.04139261e+01])

# %% [markdown]
# indexing의 혼돈을 피하기 위해 ``loc``, ``iloc``,  ``ix`` attribute를 사용한다.

# %%
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127

# %% [markdown]
# ``loc``을 사용하여 동일한 결과를 만들 수 있다.

# %%
data.loc[:'Illinois', :'pop']
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %% [markdown]
# ``ix``은 혼합된 방법이다.

# %%
data.ix[:3, :'pop']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# a:\Git\School\DataScience\Lecture_contents\Pandas\PDSH03.02-Data-Indexing-and-Selection.ipynb Cell 61' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/a%3A/Git/School/DataScience/Lecture_contents/Pandas/PDSH03.02-Data-Indexing-and-Selection.ipynb#ch0000058?line=0'>1</a> data.ix[:3, :'pop']
#
# File A:\Python\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    <a href='file:///a%3A/Python/lib/site-packages/pandas/core/generic.py?line=5575'>5576</a> if (
#    <a href='file:///a%3A/Python/lib/site-packages/pandas/core/generic.py?line=5576'>5577</a>     name not in self._internal_names_set
#    <a href='file:///a%3A/Python/lib/site-packages/pandas/core/generic.py?line=5577'>5578</a>     and name not in self._metadata
# ...

# %% [markdown]
# 이러한 것들과 기존 NumPy-style access와 결합될 수 있다.
# 아래 예는 ``loc``와 masking 및 fancy indexing이 결합된 것 이다.

# %%
data.loc[data.density > 100, ['pop', 'density']]
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %% [markdown]
# Data 변경도 물론 이뤄진다.

# %%
data.iloc[0, 2] = 90
#data.loc['California', 'density'] = 80
# data.at['California', 'density'] = 70
data
# Out:
#               area       pop     density
# California  423967  38332521   90.000000
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# ### Additional indexing conventions
#
# 반복적으로 다음 몇 가지 관례적 사용법을 눈여겨 보자.

# %%
data['Florida':'Illinois']
# Out:
#             area
# Florida   170312
# Illinois  149995

# %%
data[1:3]
# Out:
#             area
# Texas     695662
# New York  141297

# %%
data[data.density > 100]
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# New York  141297  19651127  139.076746

# %% [markdown]
# ## Iteration

# %%
for index, content in data.items() : #items() = colums 방향으로 데이터 출력
    print(f"index = {index}")
    print(content) # content의 dtype = Series.
    # DataFrame에서 가져오면 열이나 행을 가져오면 그 값의 dtype은 Series
# Out:
# index = area
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64
# index = pop
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# Name: pop, dtype: int64
# index = density
# California     90.413926
# Texas          38.018740
# New York      139.076746
# Florida       114.806121
# Illinois       85.883763
# Name: density, dtype: float64

# %%
for index, row in data.iterrows(): # row 출력
    print(f"index = {index}")
    print(row)
# Out:
# index = California
# area       4.239670e+05
# pop        3.833252e+07
# density    9.041393e+01
# Name: California, dtype: float64
# index = Texas
# area       6.956620e+05
# pop        2.644819e+07
# density    3.801874e+01
# Name: Texas, dtype: float64
# index = New York
# area       1.412970e+05
# pop        1.965113e+07
# density    1.390767e+02
# Name: New York, dtype: float64
# index = Florida
# area       1.703120e+05
# pop        1.955286e+07
# density    1.148061e+02
# Name: Florida, dtype: float64
# index = Illinois
# area       1.499950e+05
# pop        1.288214e+07
# density    8.588376e+01
# Name: Illinois, dtype: float64
