# %% [markdown]
# # Aggregation and Grouping

# %% [markdown]
# NumPy에서처럼 ``sum()``, ``mean()``, ``median()``, ``min()``,  ``max()``과 같은 aggregation 연산을 Pandas에서도 할 수 있으며 ``groupby``를 통해 보다 복잡한 형태도 가능하다.

# %%
import numpy as np
import pandas as pd

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %% [markdown]
# ## Planets Data
#
# [Seaborn package](http://seaborn.pydata.org/) 내 Planets dataset을 예로 사용해 보자. (외부행성 발견 데이터).

# %%
import seaborn as sns
planets = sns.load_dataset('planets')
planets.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# a:\Git\School\DataScience\Lecture_contents\Pandas\Aggregation(연산모듈)과groupby(왜사용).ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/a%3A/Git/School/DataScience/Lecture_contents/Pandas/Aggregation%28%EC%97%B0%EC%82%B0%EB%AA%A8%EB%93%88%29%EA%B3%BCgroupby%28%EC%99%9C%EC%82%AC%EC%9A%A9%29.ipynb#ch0000004?line=0'>1</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/a%3A/Git/School/DataScience/Lecture_contents/Pandas/Aggregation%28%EC%97%B0%EC%82%B0%EB%AA%A8%EB%93%88%29%EA%B3%BCgroupby%28%EC%99%9C%EC%82%AC%EC%9A%A9%29.ipynb#ch0000004?line=1'>2</a> planets = sns.load_dataset('planets')
# ...

# %%
planets.head() ### tail()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ## Simple Aggregation in Pandas

# %% [markdown]
# Pandas ``Series`` object에 대해서 aggregation 연산을 수행할 수 있다.

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.rand(5))
ser
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64

# %%
ser.sum()
# Out:
# 2.811925491708157

# %%
ser.mean()
# Out:
# 0.5623850983416314

# %% [markdown]
# ``DataFrame``은 default로 column단위 aggregation 결과가 나온다.

# %%
df = pd.DataFrame({'A': rng.rand(5),
                   'B': rng.rand(5)})
df
# Out:
#           A         B
# 0  0.155995  0.020584
# 1  0.058084  0.969910
# 2  0.866176  0.832443
# 3  0.601115  0.212339
# 4  0.708073  0.181825

# %%
df.mean()
# Out:
# A    0.477888
# B    0.443420
# dtype: float64

# %% [markdown]
# ``axis`` argument를 통해 변경할 수 있다.

# %%
df.mean(axis='columns')
# Out:
# 0    0.088290
# 1    0.513997
# 2    0.849309
# 3    0.406727
# 4    0.444949
# dtype: float64

# %% [markdown]
# 편리하게 ``describe()`` method를 이용하여 주요 aggregation 결과를 출력한다. (dropna()는 missing value row를 삭제한다)

# %%
planets.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %% [markdown]
# 아래 표는 built-in Pandas aggregation 함수를 요약한 것이다.
#
# | Aggregation              | Description                     |
# |--------------------------|---------------------------------|
# | ``count()``              | Total number of items           |
# | ``first()``, ``last()``  | First and last item             |
# | ``mean()``, ``median()`` | Mean and median                 |
# | ``min()``, ``max()``     | Minimum and maximum             |
# | ``std()``, ``var()``     | Standard deviation and variance |
# | ``mad()``                | Mean absolute deviation         |
# | ``prod()``               | Product of all items            |
# | ``sum()``                | Sum of all items                |

# %% [markdown]
# ## GroupBy: Split, Apply, Combine
#
# 조건에 따른 aggregation 연산을 위해 ``groupby`` operation을 이용하면 *split, apply, combine* 순서로 진행된다.

# %% [markdown]
# ### Split, apply, combine

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data': range(6)}, columns=['key', 'data'])
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %% [markdown]
# ``DataFrame``의 ``groupby()`` method를 호출시 key column을 전달하면 된다.

# %%
df.groupby('key')

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %% [markdown]
# ### The GroupBy object
#
# ``GroupBy`` object는 매우 유연하게 구현되어서 *aggregate*, *filter*, *transform*, *apply* 등에 활용할 수 있다.
# 그 전에 기본적인 ``GroupBy`` operation을 살펴보자.

# %% [markdown]
# #### Column indexing

# %%
planets.groupby('method')

# %%
planets.groupby('method')['orbital_period']

# %%
planets.groupby('method').count()
# Out:
#                                number  orbital_period  mass  distance  year
# method
# Astrometry                          2               2     0         2     2
# Eclipse Timing Variations           9               9     2         4     9
# Imaging                            38              12     0        32    38
# Microlensing                       23               7     0        10    23
# Orbital Brightness Modulation       3               3     0         2     3
# Pulsar Timing                       5               5     0         1     5
# Pulsation Timing Variations         1               1     0         0     1
# Radial Velocity                   553             553   510       530   553
# Transit                           397             397     1       224   397
# Transit Timing Variations           4               3     0         3     4

# %%
planets.groupby('method')['orbital_period'].median()
# Out:
# method
# Astrometry                         631.180000
# Eclipse Timing Variations         4343.500000
# Imaging                          27500.000000
# Microlensing                      3300.000000
# Orbital Brightness Modulation        0.342887
# Pulsar Timing                       66.541900
# Pulsation Timing Variations       1170.000000
# Radial Velocity                    360.200000
# Transit                              5.714932
# Transit Timing Variations           57.011000
# Name: orbital_period, dtype: float64

# %% [markdown]
# #### Iteration over groups

# %%
for (method, group) in planets.groupby('method'):
    print("{0:30s} shape={1}".format(method, group.shape))
# Out:
# Astrometry                     shape=(2, 6)
# Eclipse Timing Variations      shape=(9, 6)
# Imaging                        shape=(38, 6)
# Microlensing                   shape=(23, 6)
# Orbital Brightness Modulation  shape=(3, 6)
# Pulsar Timing                  shape=(5, 6)
# Pulsation Timing Variations    shape=(1, 6)
# Radial Velocity                shape=(553, 6)
# Transit                        shape=(397, 6)
# Transit Timing Variations      shape=(4, 6)

# %% [markdown]
# ### Aggregate, filter, transform, apply

# %%
rng = np.random.RandomState(0)
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': rng.randint(0, 10, 6)},
                   columns = ['key', 'data1', 'data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# #### Aggregation
#
# 앞서 aggregation 작업을 여러가지 실행할 수 있다.

# %%
df.groupby('key').aggregate(['min', np.median, max])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9

# %% [markdown]
# 특정 column별로 적용하고자 하는 aggregation operation을 지정할 수도 있다.

# %%
df.groupby('key').aggregate({'data1': 'min',
                             'data2': 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %% [markdown]
# #### Filtering
#
# filtering operation은 조건을 만족하지 않는 특정 그룹을 제거할 수 있다.

# %%
def filter_func(x):
    return x['data2'].std() > 4

display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)")
# Out:
# df
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#
# df.groupby('key').std()
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641
#
# df.groupby('key').filter(filter_func)
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# #### Transformation
# 다음과 같은 그룹별 데이터 변환이 가능하다.

# %%
df.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %% [markdown]
# #### The apply() method
#
# ``apply()`` method를 통해 임의의 함수를 그룹단위로 적용시킬 수 있다.

# %%
def norm_by_data2(x):
    # x is a DataFrame of group values
    x['data1'] /= x['data2'].sum()
    return x

display('df', "df.groupby('key').apply(norm_by_data2)")
# Out:
# df
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#
# df.groupby('key').apply(norm_by_data2)
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.142857      0
# 2   C  0.166667      3
# 3   A  0.375000      3
# 4   B  0.571429      7
# 5   C  0.416667      9

# %% [markdown]
# ### Specifying the split key
#
# 앞서 단일 column name을 기준으로 grouping하였는데 다른 방법들도 가능하다.

# %% [markdown]
# #### A list, array, series, or index providing the grouping keys
#
# Data 크기가 같은 Series나 list를 key로 사용할 수 있다.

# %%
L = [0, 1, 0, 1, 2, 1]
display('df', 'df.groupby(L).sum()')
# Out:
# 'df'
# 'df.groupby(L).sum()'

# %% [markdown]
# #### A dictionary or series mapping index to group
#
# index를 group key로 매핑한 dictionary를 사용할 수 있다.

# %%
df2 = df.set_index('key')
mapping = {'A': 'vowel', 'B': 'consonant', 'C': 'consonant'}
display('df2', 'df2.groupby(mapping).sum()')
# Out:
# df2
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# A        3      3
# B        4      7
# C        5      9
#
# df2.groupby(mapping).sum()
#            data1  data2
# consonant     12     19
# vowel          3      8

# %% [markdown]
# #### Any Python function
#
# index값을 처리할 수 있는 임의의 Python function도 가능하다.

# %%
display('df2', 'df2.groupby(str.lower).mean()')
# Out:
# df2
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# A        3      3
# B        4      7
# C        5      9
#
# df2.groupby(str.lower).mean()
#    data1  data2
# a    1.5    4.0
# b    2.5    3.5
# c    3.5    6.0

# %% [markdown]
# #### A list of valid keys
#
# 위에서 언급한 것들을 묶어서 전달할 수도 있다.

# %%
df2.groupby([str.lower, mapping]).mean()
# Out:
#              data1  data2
# a vowel        1.5    4.0
# b consonant    2.5    3.5
# c consonant    3.5    6.0

# %% [markdown]
# ### Grouping example

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
decade = 10 * (planets['year'] // 10)
decade = decade.astype(str) + 's'
decade.name = 'decade'
planets.groupby(['method', decade])['number'].sum().unstack().fillna(0)
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    5.0   10.0
# Imaging                          0.0    0.0   29.0   21.0
# Microlensing                     0.0    0.0   12.0   15.0
# Orbital Brightness Modulation    0.0    0.0    0.0    5.0
# Pulsar Timing                    0.0    9.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   52.0  475.0  424.0
# Transit                          0.0    0.0   64.0  712.0
# Transit Timing Variations        0.0    0.0    0.0    9.0
